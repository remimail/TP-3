# %%
# !pip install yfinance
# !pip install git+https://github.com/dcajasn/Riskfolio-Lib.git
# !pip install PyPortfolioOpt

#Faut changer notre version de numpy et pandas, pour l'avant dernière
# !pip install Numpy==1.23.5
# !pip install pandas==1.3.2
# Out:
# Requirement already satisfied: yfinance in /Users/Sam/anaconda3/lib/python3.11/site-packages (0.2.31)
# Requirement already satisfied: pandas>=1.3.0 in /Users/Sam/anaconda3/lib/python3.11/site-packages (from yfinance) (2.0.3)
# Requirement already satisfied: numpy>=1.16.5 in /Users/Sam/anaconda3/lib/python3.11/site-packages (from yfinance) (1.24.3)
# Requirement already satisfied: requests>=2.31 in /Users/Sam/anaconda3/lib/python3.11/site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/Sam/anaconda3/lib/python3.11/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /Users/Sam/anaconda3/lib/python3.11/site-packages (from yfinance) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in /Users/Sam/anaconda3/lib/python3.11/site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in /Users/Sam/anaconda3/lib/python3.11/site-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/Sam/anaconda3/lib/python3.11/site-packages (from yfinance) (2.3.8)
# Requirement already satisfied: peewee>=3.16.2 in /Users/Sam/anaconda3/lib/python3.11/site-packages (from yfinance) (3.17.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/Sam/anaconda3/lib/python3.11/site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: html5lib>=1.1 in /Users/Sam/anaconda3/lib/python3.11/site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/Sam/anaconda3/lib/python3.11/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4)
# Requirement already satisfied: six>=1.9 in /Users/Sam/anaconda3/lib/python3.11/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /Users/Sam/anaconda3/lib/python3.11/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/Sam/anaconda3/lib/python3.11/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /Users/Sam/anaconda3/lib/python3.11/site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/Sam/anaconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/Sam/anaconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/Sam/anaconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/Sam/anaconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (2023.7.22)
# Collecting git+https://github.com/dcajasn/Riskfolio-Lib.git
#   Cloning https://github.com/dcajasn/Riskfolio-Lib.git to /private/tmp/pip-req-build-qibkyn2x
#   Running command git clone --filter=blob:none --quiet https://github.com/dcajasn/Riskfolio-Lib.git /private/tmp/pip-req-build-qibkyn2x
#   Resolved https://github.com/dcajasn/Riskfolio-Lib.git to commit 158f4bbcc3bf5f3699a754ddb65d076a0b5b17f2
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.18.0 in /Users/Sam/anaconda3/lib/python3.11/site-packages (from Riskfolio-Lib==4.4.2) (1.24.3)
# Requirement already satisfied: scipy>=1.1.0 in /Users/Sam/anaconda3/lib/python3.11/site-packages (from Riskfolio-Lib==4.4.2) (1.11.1)
# Requirement already satisfied: pandas>=1.0.0 in /Users/Sam/anaconda3/lib/python3.11/site-packages (from Riskfolio-Lib==4.4.2) (2.0.3)
# Requirement already satisfied: matplotlib>=3.5.0 in /Users/Sam/anaconda3/lib/python3.11/site-packages (from Riskfolio-Lib==4.4.2) (3.7.2)
# Collecting cvxpy>=1.3.1 (from Riskfolio-Lib==4.4.2)
#   Obtaining dependency information for cvxpy>=1.3.1 from https://files.pythonhosted.org/packages/63/60/b800666fc77b6950464eaa0060db25473fa2eac70b9c60a0709515d05594/cvxpy-1.4.1-cp311-cp311-macosx_10_9_x86_64.whl.metadata
#   Downloading cvxpy-1.4.1-cp311-cp311-macosx_10_9_x86_64.whl.metadata (8.8 kB)
# Requirement already satisfied: scikit-learn>=1.0.0 in /Users/Sam/anaconda3/lib/python3.11/site-packages (from Riskfolio-Lib==4.4.2) (1.3.0)
# Requirement already satisfied: statsmodels>=0.10.1 in /Users/Sam/anaconda3/lib/python3.11/site-packages (from Riskfolio-Lib==4.4.2) (0.14.0)
# Collecting arch>=4.15 (from Riskfolio-Lib==4.4.2)
#   Obtaining dependency information for arch>=4.15 from https://files.pythonhosted.org/packages/f5/dd/e8543abd518461f783ad5b8465199d4ce6b7fbc4aa1d36031c44fe4b356a/arch-6.2.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata
#   Downloading arch-6.2.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata (13 kB)
# Collecting xlsxwriter>=1.3.7 (from Riskfolio-Lib==4.4.2)
#   Obtaining dependency information for xlsxwriter>=1.3.7 from https://files.pythonhosted.org/packages/f7/3e/05ba2194cd5073602422859c949a4f21310a3c49bf8dccde9e03d4522b11/XlsxWriter-3.1.9-py3-none-any.whl.metadata
#   Downloading XlsxWriter-3.1.9-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: networkx>=2.5.1 in /Users/Sam/anaconda3/lib/python3.11/site-packages (from Riskfolio-Lib==4.4.2) (3.1)
# Requirement already satisfied: astropy>=4.3.1 in /Users/Sam/anaconda3/lib/python3.11/site-packages (from Riskfolio-Lib==4.4.2) (5.1)
# Collecting pybind11>=2.10.1 (from Riskfolio-Lib==4.4.2)
#   Obtaining dependency information for pybind11>=2.10.1 from https://files.pythonhosted.org/packages/06/55/9f73c32dda93fa4f539fafa268f9504e83c489f460c380371d94296126cd/pybind11-2.11.1-py3-none-any.whl.metadata
#   Using cached pybind11-2.11.1-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: pyerfa>=2.0 in /Users/Sam/anaconda3/lib/python3.11/site-packages (from astropy>=4.3.1->Riskfolio-Lib==4.4.2) (2.0.0)
# Requirement already satisfied: PyYAML>=3.13 in /Users/Sam/anaconda3/lib/python3.11/site-packages (from astropy>=4.3.1->Riskfolio-Lib==4.4.2) (6.0)
# Requirement already satisfied: packaging>=19.0 in /Users/Sam/anaconda3/lib/python3.11/site-packages (from astropy>=4.3.1->Riskfolio-Lib==4.4.2) (23.1)
# Collecting osqp>=0.6.2 (from cvxpy>=1.3.1->Riskfolio-Lib==4.4.2)
#   Obtaining dependency information for osqp>=0.6.2 from https://files.pythonhosted.org/packages/9a/08/bd3cacf6b99d639f99b276219553e74f8f800888ec0e01a39cb0ca22f0f1/osqp-0.6.3-cp311-cp311-macosx_10_9_x86_64.whl.metadata
#   Downloading osqp-0.6.3-cp311-cp311-macosx_10_9_x86_64.whl.metadata (1.7 kB)
# Collecting ecos>=2 (from cvxpy>=1.3.1->Riskfolio-Lib==4.4.2)
#   Downloading ecos-2.0.12-cp311-cp311-macosx_10_9_x86_64.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 2.3 MB/s eta 0:00:00ta 0:00:01
# Collecting clarabel>=0.5.0 (from cvxpy>=1.3.1->Riskfolio-Lib==4.4.2)
#   Obtaining dependency information for clarabel>=0.5.0 from https://files.pythonhosted.org/packages/55/1e/16864d79381d95d5c1eea427295b8d927c7964f1b5a388ad8c3d5b75ab3a/clarabel-0.6.0-cp37-abi3-macosx_10_9_x86_64.macosx_11_0_arm64.macosx_10_9_universal2.whl.metadata
#   Downloading clarabel-0.6.0-cp37-abi3-macosx_10_9_x86_64.macosx_11_0_arm64.macosx_10_9_universal2.whl.metadata (4.4 kB)
# Collecting scs>=3.0 (from cvxpy>=1.3.1->Riskfolio-Lib==4.4.2)
#   Obtaining dependency information for scs>=3.0 from https://files.pythonhosted.org/packages/65/e6/fe0c2aecec11c3cb1f969ebee88dd4ca10d5a1def0124d07f83fe3d6e127/scs-3.2.4-cp311-cp311-macosx_10_9_x86_64.whl.metadata
#   Downloading scs-3.2.4-cp311-cp311-macosx_10_9_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/Sam/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.5.0->Riskfolio-Lib==4.4.2) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/Sam/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.5.0->Riskfolio-Lib==4.4.2) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/Sam/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.5.0->Riskfolio-Lib==4.4.2) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/Sam/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.5.0->Riskfolio-Lib==4.4.2) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/Sam/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.5.0->Riskfolio-Lib==4.4.2) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/Sam/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.5.0->Riskfolio-Lib==4.4.2) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/Sam/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.5.0->Riskfolio-Lib==4.4.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/Sam/anaconda3/lib/python3.11/site-packages (from pandas>=1.0.0->Riskfolio-Lib==4.4.2) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/Sam/anaconda3/lib/python3.11/site-packages (from pandas>=1.0.0->Riskfolio-Lib==4.4.2) (2023.3)
# Requirement already satisfied: joblib>=1.1.1 in /Users/Sam/anaconda3/lib/python3.11/site-packages (from scikit-learn>=1.0.0->Riskfolio-Lib==4.4.2) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/Sam/anaconda3/lib/python3.11/site-packages (from scikit-learn>=1.0.0->Riskfolio-Lib==4.4.2) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in /Users/Sam/anaconda3/lib/python3.11/site-packages (from statsmodels>=0.10.1->Riskfolio-Lib==4.4.2) (0.5.3)
# Collecting qdldl (from osqp>=0.6.2->cvxpy>=1.3.1->Riskfolio-Lib==4.4.2)
#   Obtaining dependency information for qdldl from https://files.pythonhosted.org/packages/85/44/8821dc9d8b62fac20430f98c379856f9008388eebecbe6dd16a08231b030/qdldl-0.1.7.post0-cp311-cp311-macosx_10_9_x86_64.whl.metadata
#   Downloading qdldl-0.1.7.post0-cp311-cp311-macosx_10_9_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: six in /Users/Sam/anaconda3/lib/python3.11/site-packages (from patsy>=0.5.2->statsmodels>=0.10.1->Riskfolio-Lib==4.4.2) (1.16.0)
# Downloading arch-6.2.0-cp311-cp311-macosx_10_9_x86_64.whl (951 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 951.4/951.4 kB 4.3 MB/s eta 0:00:0000:0100:01
# Downloading cvxpy-1.4.1-cp311-cp311-macosx_10_9_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 5.2 MB/s eta 0:00:0000:0100:01
# Using cached pybind11-2.11.1-py3-none-any.whl (227 kB)
# Downloading XlsxWriter-3.1.9-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 3.2 MB/s eta 0:00:0000:01
# Downloading clarabel-0.6.0-cp37-abi3-macosx_10_9_x86_64.macosx_11_0_arm64.macosx_10_9_universal2.whl (987 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 987.4/987.4 kB 6.7 MB/s eta 0:00:00a 0:00:01
# Downloading osqp-0.6.3-cp311-cp311-macosx_10_9_x86_64.whl (252 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.6/252.6 kB 4.0 MB/s eta 0:00:00a 0:00:01
# Downloading scs-3.2.4-cp311-cp311-macosx_10_9_x86_64.whl (109 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.2/109.2 kB 2.2 MB/s eta 0:00:00ta 0:00:01
# Downloading qdldl-0.1.7.post0-cp311-cp311-macosx_10_9_x86_64.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.2/105.2 kB 2.4 MB/s eta 0:00:00ta 0:00:01
# Building wheels for collected packages: Riskfolio-Lib
#   Building wheel for Riskfolio-Lib (pyproject.toml) ... \

# %%
run data.py
# Out:
# [*********************100%%**********************]  11 of 11 completed

# %%
#Annualized variance of returns
np.sqrt(rets.var()*252)
# Out:
# EAGG    0.057455
# ESGD    0.198256
# ESGE    0.222815
# ESGU    0.219349
# ESML    0.258482
# GOVT    0.059934
# MBB     0.060113
# SHY     0.017909
# SUSA    0.217643
# SUSB    0.044849
# SUSC    0.090233
# dtype: float64

# %% [markdown]
# ## Risk parity relaxed optim based on historical rets and cov

# %%
version = 'A' # Could be A, B or C

w_rrp_a = port.rrp_optimization(model=model, version=version, l=l, b= None, hist=hist)

display(w_rrp_a.T)
# Plotting the composition of the portfolio

ax = rp.plot_pie(w=w_rrp_a, title='Relaxed Risk Parity A', others=0.05, nrow=25, cmap = "tab20",
                 height=6, width=10, ax=None)
# Out:
# /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages/cvxpy/problems/problem.py:1387: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
#              EAGG      ESGD      ESGE      ESGU      ESML      GOVT       MBB  \
# weights  0.116152  0.047068  0.045582  0.042421  0.036066  0.137479  0.109873
#
#               SHY     SUSA      SUSB      SUSC
# weights  0.208064  0.04286  0.129538  0.084896

# %%
from pypfopt import black_litterman, risk_models
from pypfopt import BlackLittermanModel, plotting

S = risk_models.CovarianceShrinkage(etf_prices).ledoit_wolf()
market_prior = w_rrp_a

viewdict = {
    "ESGU": 0.10,
    "EAGG": 0.30,
    "ESGE": 0.05,
    "ESML": 0.05,
    "SUSB": 0.20,
    "ESGD": -0.05,  # Negative view on ESGD
    "SHY": 0.15,
    "SUSA": 0.10,
    "GOVT": 0.50,  # Low confidence in the positive view on GOVT
    "MBB": 0.10,
    "SUSC": 0.10
}

confidences = [
    0.6,
    0.4,
    0.2,
    0.5,
    0.7, # confident in dominos
    0.7, # confident KO will do poorly
    0.7, 
    0.5,
    0.1,
    0.4,
    0.1
]

# %%
bl = BlackLittermanModel(S, pi=market_prior, absolute_views=viewdict, omega="idzorek", view_confidences=confidences)

# Posterior estimate of returns
ret_bl = bl.bl_returns()
ret_bl
# Out:
# EAGG    0.172466
# ESGD    0.027057
# ESGE    0.037531
# ESGU    0.051617
# ESML    0.041604
# GOVT    0.181658
# MBB     0.133383
# SHY     0.175818
# SUSA    0.051074
# SUSB    0.178640
# SUSC    0.171122
# dtype: float64

# %%
import pandas as pd
import numpy as np

# Assuming market_prior is a DataFrame and ret_bl is a Series
market_prior_values = market_prior.values.flatten()
ret_bl_values = ret_bl.values.flatten()


# Create the DataFrame
rets_df = pd.DataFrame({
    "Prior": market_prior_values,
    "Posterior": ret_bl_values,
    "Views": pd.Series(viewdict)
})

# Display the DataFrame
print(rets_df)
# Out:
#          Prior  Posterior  Views
# ESGU  0.116152   0.172466   0.10
# EAGG  0.047068   0.027057   0.30
# ESGE  0.045582   0.037531   0.05
# ESML  0.042421   0.051617   0.05
# SUSB  0.036066   0.041604   0.20
# ESGD  0.137479   0.181658  -0.05
# SHY   0.109873   0.133383   0.15
# SUSA  0.208064   0.175818   0.10
# GOVT  0.042860   0.051074   0.50
# MBB   0.129538   0.178640   0.10
# SUSC  0.084896   0.171122   0.10

# %%
rets_df.plot.bar(figsize=(12,8));
