# %%
# !pip install yfinance
# !pip install git+https://github.com/dcajasn/Riskfolio-Lib.git
# !pip install PyPortfolioOpt

#Faut changer notre version de numpy et pandas, pour l'avant dernière
# !pip install Numpy==1.23.5
# !pip install pandas==1.3.2
# Out:
# Requirement already satisfied: yfinance in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (0.2.31)
# Requirement already satisfied: appdirs>=1.4.4 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from yfinance) (2.3.8)
# Requirement already satisfied: html5lib>=1.1 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from yfinance) (1.1)
# Requirement already satisfied: requests>=2.31 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: numpy>=1.16.5 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from yfinance) (1.23.5)
# Requirement already satisfied: pandas>=1.3.0 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from yfinance) (1.3.2)
# Requirement already satisfied: lxml>=4.9.1 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from yfinance) (4.9.3)
# Requirement already satisfied: peewee>=3.16.2 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from yfinance) (3.17.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: pytz>=2022.5 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: six>=1.9 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from html5lib>=1.1->yfinance) (1.15.0)
# Requirement already satisfied: webencodings in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.31->yfinance) (1.25.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.31->yfinance) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.31->yfinance) (2020.6.20)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: soupsieve>1.2 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.0.1)
# Collecting git+https://github.com/dcajasn/Riskfolio-Lib.git
#   Cloning https://github.com/dcajasn/Riskfolio-Lib.git to /private/var/folders/k5/ktrf3j117gs1ppk87tw6dxbc0000gn/T/pip-req-build-z86lvq0e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied (use --upgrade to upgrade): Riskfolio-Lib==4.4.2 from git+https://github.com/dcajasn/Riskfolio-Lib.git in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages
# Requirement already satisfied: pybind11>=2.10.1 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from Riskfolio-Lib==4.4.2) (2.11.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from Riskfolio-Lib==4.4.2) (1.3.2)
# Requirement already satisfied: arch>=4.15 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from Riskfolio-Lib==4.4.2) (5.6.0)
# Requirement already satisfied: astropy>=4.3.1 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from Riskfolio-Lib==4.4.2) (5.2.2)
# Requirement already satisfied: matplotlib>=3.5.0 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from Riskfolio-Lib==4.4.2) (3.7.3)
# Requirement already satisfied: xlsxwriter>=1.3.7 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from Riskfolio-Lib==4.4.2) (1.3.7)
# Requirement already satisfied: networkx>=2.5.1 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from Riskfolio-Lib==4.4.2) (3.1)
# Requirement already satisfied: pandas>=1.0.0 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from Riskfolio-Lib==4.4.2) (1.3.2)
# Requirement already satisfied: numpy>=1.18.0 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from Riskfolio-Lib==4.4.2) (1.23.5)
# Requirement already satisfied: cvxpy>=1.3.1 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from Riskfolio-Lib==4.4.2) (1.3.2)
# Requirement already satisfied: statsmodels>=0.10.1 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from Riskfolio-Lib==4.4.2) (0.12.0)
# Requirement already satisfied: scipy>=1.1.0 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from Riskfolio-Lib==4.4.2) (1.5.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn>=1.0.0->Riskfolio-Lib==4.4.2) (2.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn>=1.0.0->Riskfolio-Lib==4.4.2) (1.3.2)
# Requirement already satisfied: property-cached>=1.6.4 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from arch>=4.15->Riskfolio-Lib==4.4.2) (1.6.4)
# Requirement already satisfied: packaging>=19.0 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from astropy>=4.3.1->Riskfolio-Lib==4.4.2) (20.4)
# Requirement already satisfied: PyYAML>=3.13 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from astropy>=4.3.1->Riskfolio-Lib==4.4.2) (5.3.1)
# Requirement already satisfied: pyerfa>=2.0 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from astropy>=4.3.1->Riskfolio-Lib==4.4.2) (2.0.0.3)
# Requirement already satisfied: cycler>=0.10 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.5.0->Riskfolio-Lib==4.4.2) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.5.0->Riskfolio-Lib==4.4.2) (4.44.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.5.0->Riskfolio-Lib==4.4.2) (2.4.7)
# Requirement already satisfied: importlib-resources>=3.2.0; python_version < "3.10" in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.5.0->Riskfolio-Lib==4.4.2) (6.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.5.0->Riskfolio-Lib==4.4.2) (1.1.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.5.0->Riskfolio-Lib==4.4.2) (8.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.5.0->Riskfolio-Lib==4.4.2) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.5.0->Riskfolio-Lib==4.4.2) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from pandas>=1.0.0->Riskfolio-Lib==4.4.2) (2023.3.post1)
# Requirement already satisfied: osqp>=0.4.1 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from cvxpy>=1.3.1->Riskfolio-Lib==4.4.2) (0.6.3)
# Requirement already satisfied: scs>=1.1.6 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from cvxpy>=1.3.1->Riskfolio-Lib==4.4.2) (3.2.3)
# Requirement already satisfied: ecos>=2 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from cvxpy>=1.3.1->Riskfolio-Lib==4.4.2) (2.0.12)
# Requirement already satisfied: setuptools>65.5.1 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from cvxpy>=1.3.1->Riskfolio-Lib==4.4.2) (68.2.2)
# Requirement already satisfied: patsy>=0.5 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from statsmodels>=0.10.1->Riskfolio-Lib==4.4.2) (0.5.1)
# Requirement already satisfied: six in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from packaging>=19.0->astropy>=4.3.1->Riskfolio-Lib==4.4.2) (1.15.0)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from importlib-resources>=3.2.0; python_version < "3.10"->matplotlib>=3.5.0->Riskfolio-Lib==4.4.2) (3.4.0)
# Requirement already satisfied: qdldl in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from osqp>=0.4.1->cvxpy>=1.3.1->Riskfolio-Lib==4.4.2) (0.1.7.post0)
# Building wheels for collected packages: Riskfolio-Lib
#   Building wheel for Riskfolio-Lib (PEP 517) ... done
#   Created wheel for Riskfolio-Lib: filename=Riskfolio_Lib-4.4.2-cp38-cp38-macosx_10_14_x86_64.whl size=183430 sha256=2baf5ac168bcd5ab947badcbbd2f2ff8049e6bb24c94f5339953ccae397557ea
#   Stored in directory: /private/var/folders/k5/ktrf3j117gs1ppk87tw6dxbc0000gn/T/pip-ephem-wheel-cache-75r64ge5/wheels/32/11/d0/056926a99810470e8134d20f48757fcc5180097befacd82dd8
# Successfully built Riskfolio-Lib
# Requirement already satisfied: PyPortfolioOpt in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (1.5.5)
# Requirement already satisfied: numpy<2.0.0,>=1.22.4 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from PyPortfolioOpt) (1.23.5)
# Requirement already satisfied: cvxpy<2.0.0,>=1.1.19 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from PyPortfolioOpt) (1.3.2)
# Requirement already satisfied: scipy<2.0,>=1.3 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from PyPortfolioOpt) (1.5.2)
# Requirement already satisfied: pandas>=0.19 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from PyPortfolioOpt) (1.3.2)
# Requirement already satisfied: ecos>=2 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from cvxpy<2.0.0,>=1.1.19->PyPortfolioOpt) (2.0.12)
# Requirement already satisfied: osqp>=0.4.1 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from cvxpy<2.0.0,>=1.1.19->PyPortfolioOpt) (0.6.3)
# Requirement already satisfied: setuptools>65.5.1 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from cvxpy<2.0.0,>=1.1.19->PyPortfolioOpt) (68.2.2)
# Requirement already satisfied: scs>=1.1.6 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from cvxpy<2.0.0,>=1.1.19->PyPortfolioOpt) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.19->PyPortfolioOpt) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.19->PyPortfolioOpt) (2023.3.post1)
# Requirement already satisfied: qdldl in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from osqp>=0.4.1->cvxpy<2.0.0,>=1.1.19->PyPortfolioOpt) (0.1.7.post0)
# Requirement already satisfied: six>=1.5 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.19->PyPortfolioOpt) (1.15.0)
# Requirement already satisfied: Numpy==1.23.5 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (1.23.5)
# Requirement already satisfied: pandas==1.3.2 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (1.3.2)
# Requirement already satisfied: numpy>=1.17.3 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from pandas==1.3.2) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from pandas==1.3.2) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from pandas==1.3.2) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas==1.3.2) (1.15.0)

# %%
run data.py
# Out:
# [*********************100%%**********************]  11 of 11 completed

# %%
# Tickers list
# We can add and delete any ticker from the list to get desired ticker live data
ticker_list=['ESGU', 'EAGG', 'ESGE', 'ESML', 'SUSB', 'ESGD', 'SHY', 'SUSA' , 'GOVT', 'MBB', 'SUSC']

etf_monthly_rets = getData(ticker_list)
# Out:
# [*********************100%%**********************]  11 of 11 completed

# %%
# DOES NOT INCLUDE ALL THE TICKERS (missing GOVT and SUSA)
ticker_list_sub=['ESGU', 'EAGG', 'ESGE', 'ESML', 'SUSB', 'ESGD', 'SHY', 'MBB', 'SUSC']

# %%
# Importing ETF benchmark indexes
df_index = pd.DataFrame()
for i in ticker_list_sub:
    csv_file_path = (f'data/{i}_index.csv')
# Example usage
    stored_serie = import_csv_with_date_index(csv_file_path)
    df_index = pd.concat([df_index, stored_serie], axis=1)

df_index.columns = ticker_list_sub
df_index_rets = df_index.pct_change()   
df_index_rets = df_index_rets.iloc[1:,:]


# Generate values for nas
# Create a KNNImputer instance
imputer = KNNImputer(n_neighbors=5)  # You can adjust the number of neighbors as needed
# Fit the imputer on the data and transform the DataFrame
df_imputed_index = pd.DataFrame(imputer.fit_transform(df_index_rets), columns=df_index_rets.columns, index=df_index_rets.index)

# %%
# Grid of histograms of the Indexes monthly returns 

# Get the list of all column names
columns = df_imputed_index.columns

# Determine the number of rows and columns for the grid
num_rows = 3
num_cols = 3

# Create a figure and subplots
fig, axs = plt.subplots(num_rows, num_cols, figsize=(16, 16))
fig.suptitle("Histograms of Indexes monthly returns", fontsize=18)

# Flatten the axs array for easier indexing
axs = axs.flatten()

# Loop through the columns and plot histograms
for i, column in enumerate(columns):
    if i >= num_rows * num_cols:
        break  # Exit the loop if you exceed the number of subplots
    
    ax = axs[i]
    df_imputed_index[column].hist(ax=ax, bins=50)  # You can adjust the number of bins as needed
    ax.set_title(column)
    ax.set_xlabel("Value")
    ax.set_ylabel("Frequency")
    print(df_imputed_index[column].describe())
    print(f'Average spread of the index for the etf {column}: {np.mean(df_imputed_index[column].max()-df_imputed_index[column].min())}')
    print(f'Maximum spread of the index for the etf {column}: {np.max(df_imputed_index[column].max()-df_imputed_index[column].min())}')
    print(f'Skewness of the index for the etf {column}: {np.mean(skew(df_imputed_index[column][:], nan_policy="omit"))} ')
    print(f'Kurtosis of the index for the etf {column}: {np.mean(kurtosis(df_imputed_index[column][:], nan_policy="omit"))} ')



# Hide any empty subplots if there are more subplots than columns
for i in range(len(columns), num_rows * num_cols):
    fig.delaxes(axs[i])

plt.tight_layout()
plt.show()
# Out:
# count    283.000000
# mean       0.007107
# std        0.030191
# min       -0.072736
# 25%       -0.012475
# 50%        0.012037
# 75%        0.026975
# max        0.110611
# Name: ESGU, dtype: float64
# Average spread of the index for the etf ESGU: 0.18334701034632206
# Maximum spread of the index for the etf ESGU: 0.18334701034632206
# Skewness of the index for the etf ESGU: -0.26689548329820695
# Kurtosis of the index for the etf ESGU: 0.27292124010101615
# count    283.000000
# mean       0.003277
# std        0.010287
# min       -0.043401
# 25%       -0.000715
# 50%        0.002652
# 75%        0.010402
# max        0.036925
# Name: EAGG, dtype: float64
# Average spread of the index for the etf EAGG: 0.08032620818975811
# Maximum spread of the index for the etf EAGG: 0.08032620818975811
# Skewness of the index for the etf EAGG: -0.6366115054784772
# Kurtosis of the index for the etf EAGG: 2.448509402158723
# count    283.000000
# mean       0.002902
# std        0.032807
# min       -0.108789
# 25%       -0.015046
# 50%        0.001342
# 75%        0.023581
# max        0.140001
# Name: ESGE, dtype: float64
# Average spread of the index for the etf ESGE: 0.24878990676898827
# Maximum spread of the index for the etf ESGE: 0.24878990676898827
# Skewness of the index for the etf ESGE: 0.2632269293256912
# Kurtosis of the index for the etf ESGE: 1.0857530772413062
# count    283.000000
# mean       0.006529
# std        0.036587
# min       -0.174342
# 25%       -0.011214
# 50%        0.010083
# 75%        0.029937
# max        0.134265
# Name: ESML, dtype: float64
# Average spread of the index for the etf ESML: 0.308607041230587
# Maximum spread of the index for the etf ESML: 0.308607041230587
# Skewness of the index for the etf ESML: -0.45766637426415807
# Kurtosis of the index for the etf ESML: 2.4061047768752477
# count    283.000000
# mean       0.002311
# std        0.006034
# min       -0.035593
# 25%       -0.001178
# 50%        0.003007
# 75%        0.006018
# max        0.028778
# Name: SUSB, dtype: float64
# Average spread of the index for the etf SUSB: 0.06437117025252681
# Maximum spread of the index for the etf SUSB: 0.06437117025252681
# Skewness of the index for the etf SUSB: -0.9952018507689534
# Kurtosis of the index for the etf SUSB: 7.141335226245234
# count    283.000000
# mean       0.002069
# std        0.028451
# min       -0.082746
# 25%       -0.013543
# 50%        0.005322
# 75%        0.017765
# max        0.126511
# Name: ESGD, dtype: float64
# Average spread of the index for the etf ESGD: 0.20925727235711056
# Maximum spread of the index for the etf ESGD: 0.20925727235711056
# Skewness of the index for the etf ESGD: 0.10349357117766696
# Kurtosis of the index for the etf ESGD: 1.949700555033366
# count    283.000000
# mean      -0.002473
# std        0.007829
# min       -0.032587
# 25%       -0.005801
# 50%       -0.003516
# 75%        0.000116
# max        0.040410
# Name: SHY, dtype: float64
# Average spread of the index for the etf SHY: 0.07299795178905466
# Maximum spread of the index for the etf SHY: 0.07299795178905466
# Skewness of the index for the etf SHY: 1.1358806714063094
# Kurtosis of the index for the etf SHY: 7.042597749459134
# count    283.000000
# mean       0.002613
# std        0.009720
# min       -0.050513
# 25%       -0.000993
# 50%        0.002139
# 75%        0.007772
# max        0.040759
# Name: MBB, dtype: float64
# Average spread of the index for the etf MBB: 0.09127169933828394
# Maximum spread of the index for the etf MBB: 0.09127169933828394
# Skewness of the index for the etf MBB: -0.7565824448173258
# Kurtosis of the index for the etf MBB: 5.9369574733200725
# count    283.000000
# mean       0.004130
# std        0.014690
# min       -0.069726
# 25%       -0.003372
# 50%        0.005490
# 75%        0.013281
# max        0.056113
# Name: SUSC, dtype: float64
# Average spread of the index for the etf SUSC: 0.1258398532653454
# Maximum spread of the index for the etf SUSC: 0.1258398532653454
# Skewness of the index for the etf SUSC: -0.7951638555248957
# Kurtosis of the index for the etf SUSC: 3.712157237162341

# %%
#====================================================================================
# Grid of time seiries of the Indexes monthly returns 

# Plotting in a 3 by 4 grid
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(12, 9), sharex=True)

# Flatten the 2D array of subplots for easier indexing
axes = axes.flatten()

# Plot each column in a separate subplot
for i, column in enumerate(df_imputed_index.columns):
    df_imputed_index[column].plot(ax=axes[i], legend=True, grid=True)
    axes[i].set_title(column)
    axes[i].set_xlabel('Date')  # Set x-axis label on each subplot
    ax.set_ylabel('Return')

# Adjust layout
plt.tight_layout()
fig.suptitle('Benchmark Indexes Time Series', fontsize=16).set_y(1.01)

# Show the plot
plt.show()

# %%
df_imputed_index
# Out:
#                 ESGU      EAGG      ESGE      ESML      SUSB      ESGD  \
# Date
# 2000-12-29 -0.020554  0.017336 -0.013169 -0.038916  0.007573 -0.018144
# 2001-01-31 -0.020554  0.017336 -0.013169 -0.038916  0.007573 -0.018144
# 2001-02-28  0.017133  0.010018 -0.012107 -0.001508  0.004769 -0.000799
# 2001-03-30  0.017133  0.010018 -0.012107 -0.001508  0.004581 -0.000799
# 2001-04-30  0.019556  0.001342 -0.005001  0.029985  0.003470  0.010435
# ...              ...       ...       ...       ...       ...       ...
# 2023-06-30  0.035321 -0.003571  0.008918  0.054402 -0.002137  0.015630
# 2023-07-31  0.029793 -0.000672  0.061386  0.046461  0.006721  0.027444
# 2023-08-31  0.012264 -0.006373 -0.038494 -0.011465  0.001223 -0.010876
# 2023-09-29 -0.049761 -0.025381 -0.027960 -0.059534 -0.005197 -0.035577
# 2023-09-30  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#                  SHY       MBB      SUSC
# Date
# 2000-12-29 -0.004242  0.016101  0.014315
# 2001-01-31 -0.004242  0.015569  0.014315
# 2001-02-28 -0.011362  0.005726  0.010691
# 2001-03-30 -0.011362  0.005804  0.009856
# 2001-04-30  0.005530  0.001388  0.005832
# ...              ...       ...       ...
# 2023-06-30 -0.032587 -0.004266  0.004196
# 2023-07-31 -0.001350 -0.000746  0.003532
# 2023-08-31  0.032940 -0.008227 -0.007614
# 2023-09-29  0.000000 -0.031862 -0.026628
# 2023-09-30 -0.000354  0.000000  0.000000
#
# [283 rows x 9 columns]

# %%
# Grid of time seiries of the ETFs monthly returns 

# Determine the number of subplots based on the number of columns
num_subplots = len(etf_monthly_rets.columns)

# Calculate the number of rows and columns for the subplot grid
num_rows = int(np.ceil(num_subplots / 3))
num_cols = min(num_subplots, 3)

# Plotting in a dynamic grid
fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(12, 9), sharex=True)

# Flatten the 2D array of subplots for easier indexing
axes = axes.flatten()

# Plot each column in a separate subplot
for i, column in enumerate(etf_monthly_rets.columns):
    etf_monthly_rets[column].plot(ax=axes[i], legend=True, grid=True)
    axes[i].set_title(column)
    axes[i].set_xlabel('Date')
    axes[i].set_ylabel('Return')

# Adjust layout
plt.tight_layout()
fig.suptitle('ETFs Time Series', fontsize=16).set_y(1.01)

# %%
etf_monthly_rets
# Out:
#                 EAGG      ESGD      ESGE      ESGU      ESML      GOVT  \
# Date
# 2002-07-31  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2002-08-31  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2002-09-30  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2002-10-31  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2002-11-30  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# ...              ...       ...       ...       ...       ...       ...
# 2023-07-31 -0.002968  0.025093  0.062915  0.034886  0.052083 -0.005240
# 2023-08-31 -0.008718 -0.039192 -0.070791 -0.016359 -0.039069 -0.007463
# 2023-09-30 -0.028314 -0.037589 -0.030730 -0.053422 -0.062935 -0.025210
# 2023-10-31 -0.018322 -0.031824 -0.030053 -0.023959 -0.065379 -0.014065
# 2023-11-30  0.029683  0.074705  0.073544  0.080624  0.080763  0.023930
#
#                  MBB       SHY      SUSA      SUSB      SUSC
# Date
# 2002-07-31  0.000000  0.003086  0.000000  0.000000  0.000000
# 2002-08-31  0.000000  0.004307  0.000000  0.000000  0.000000
# 2002-09-30  0.000000  0.005759  0.000000  0.000000  0.000000
# 2002-10-31  0.000000  0.000975  0.000000  0.000000  0.000000
# 2002-11-30  0.000000 -0.005477  0.000000  0.000000  0.000000
# ...              ...       ...       ...       ...       ...
# 2023-07-31 -0.003753  0.000493  0.037057  0.003764 -0.002199
# 2023-08-31 -0.010977  0.001479 -0.016579 -0.001250 -0.010577
# 2023-09-30 -0.033732 -0.003323 -0.057906 -0.008344 -0.030735
# 2023-10-31 -0.024550  0.000741 -0.035345 -0.002945 -0.022518
# 2023-11-30  0.039598  0.003085  0.082728  0.011814  0.039962
#
# [257 rows x 11 columns]

# %%
# Select common columns
common_columns = set(etf_monthly_rets.columns) & set(df_imputed_index.columns)

# Calculate the tracking error for each common column
tracking_errors = {}
for column in common_columns:
    # Filter out rows with a value of 0 in both DataFrames
    valid_rows = (etf_monthly_rets[column] != 0) | (df_imputed_index[column] != 0)
    
    # Calculate the tracking error for valid rows
    diff = etf_monthly_rets[column][valid_rows] - df_imputed_index[column][valid_rows]
    tracking_error = np.std(diff)
    tracking_errors[column] = tracking_error

# Display the tracking errors
for column, tracking_error in tracking_errors.items():
    print(f'Tracking Error for {column}: {tracking_error}')
# Out:
# Tracking Error for SHY: 0.009970923282406357
# Tracking Error for SUSC: 0.010740404888851507
# Tracking Error for ESGE: 0.027219572896831162
# Tracking Error for EAGG: 0.007975757871260779
# Tracking Error for ESGD: 0.024415869461130328
# Tracking Error for ESGU: 0.0268830501736736
# Tracking Error for ESML: 0.030147720903850858
# Tracking Error for MBB: 0.006168187565557076
# Tracking Error for SUSB: 0.004041105368112377

# %%
# Clustermap of correlation of benchmark indexes returns

# Compute corr matrix
imputed_index_corr = pd.DataFrame(df_imputed_index).corr()

sns.clustermap(imputed_index_corr, annot=True, square=True)
plt.suptitle('Clustermap of the correlation between returns of the Benchmark Indexes').set_y(1.01)

plt.show();
# Out:
# C:\Users\Samuel\anaconda3\Lib\site-packages\seaborn\matrix.py:1124: UserWarning: ``square=True`` ignored in clustermap
#   warnings.warn(msg)

# %%
#----------------------------------------- Importation des donnees from FRED Website ------------------------------------------------
# Import Features via FRED API 

# Features lists
features_list = ['BAMLCC0A0CMTRIV', 'BAMLC0A4CBBB', 'BAMLC0A3CA', 'HQMCB10YR', 'FEDFUNDS', 'T10Y2Y', 'TB3SMFFM',
                 'T5YFF', 'T1YFF', 'DLTIIT', 'NASDAQCOM', 'WILL5000PR', 'WILLLRGCAP', 'WILLSMLCAP', 'WILLLRGCAPGR', 
                 'WILLLRGCAPVAL', 'WILLMIDCAP', 'MSPUS', 'CCSA', 'BOPGSTB', 'VIXCLS', 'USSLIND', 'USALOLITONOSTSAM', 'UNRATE', 
                 'STICKCPIM157SFRBATL', 'EMVMACROBUS', 'MORTGAGE30US',  'WILLRESIPR']


df_feat = pd.DataFrame(columns=features_list )

for i in features_list:
    try:
        data= import_fred(i)
        df_feat[i] = data.resample('M').last()
    except Exception as e:
        print(f"Error fetching data for {i}: {e}")
        
# Create a KNNImputer instance
imputer = KNNImputer(n_neighbors=5)  # You can adjust the number of neighbors as needed
# Fit the imputer on the data and transform the DataFrame
df_feat = pd.DataFrame(imputer.fit_transform(df_feat), columns=df_feat.columns, index=df_feat.index)

# Standardizing the features 


# Min-Max scaling
minmax_scaler = MinMaxScaler()
df_feat_minmax = pd.DataFrame(minmax_scaler.fit_transform(df_feat), columns=df_feat.columns)

# %%
# Clustermap of correlation of benchmark indexes returns

# Compute corr matrix
df_feat_minmax_corr = pd.DataFrame(df_feat_minmax).corr()

sns.clustermap(df_feat_minmax_corr, annot=True)
plt.suptitle('Clustermap of the correlation between standardized features').set_y(1.01)

plt.show();      # we can see that the equity market indexes are strongly correlated

# %% [markdown]
# # Remi's

# %%
rets
# Out:
#                 EAGG      ESGD      ESGE      ESGU      ESML      GOVT  \
# Date
# 2018-10-24  0.000000 -0.027891 -0.029961 -0.030399 -0.028717  0.003722
# 2018-10-25  0.000000  0.012368  0.015941  0.017743  0.012648 -0.002472
# 2018-10-26  0.000000 -0.007979 -0.008500 -0.018281 -0.011138  0.003717
# 2018-10-29  0.003195 -0.001676 -0.017474 -0.005517 -0.009654 -0.000412
# 2018-10-30 -0.001194  0.011917  0.018456  0.010679  0.016247 -0.001646
# ...              ...       ...       ...       ...       ...       ...
# 2023-11-13  0.001108  0.002022 -0.000650 -0.001552 -0.000617  0.000000
# 2023-11-14  0.009296  0.025659  0.026675  0.021030  0.048502  0.009991
# 2023-11-15 -0.002193 -0.000703  0.008872  0.001319  0.004125 -0.004946
# 2023-11-16  0.005275 -0.001688 -0.010678  0.002229 -0.013498  0.004519
# 2023-11-17  0.000216  0.010425  0.000476  0.000017  0.006841  0.000000
#
#                  MBB       SHY      SUSA      SUSB      SUSC
# Date
# 2018-10-24  0.002248  0.001566 -0.026467  0.000818  0.000963
# 2018-10-25  0.000097 -0.000361  0.016738 -0.001225  0.000293
# 2018-10-26  0.001365  0.000602 -0.009823  0.002453  0.002510
# 2018-10-29  0.000000  0.000361 -0.010655  0.000000 -0.003171
# 2018-10-30 -0.001266 -0.000481  0.020797 -0.002121 -0.001842
# ...              ...       ...       ...       ...       ...
# 2023-11-13 -0.000677  0.000370 -0.001965  0.000420  0.000000
# 2023-11-14  0.015023  0.003949  0.023414  0.006723  0.012880
# 2023-11-15 -0.007456 -0.001844  0.003314 -0.002087 -0.004087
# 2023-11-16  0.006391  0.001724  0.000320  0.001882  0.007296
# 2023-11-17 -0.001003 -0.000535  0.000107  0.000835  0.000113
#
# [1276 rows x 11 columns]

# %%
#Annualized variance of returns
np.sqrt(rets.var()*252)
# Out:
# EAGG    0.057443
# ESGD    0.198076
# ESGE    0.222638
# ESGU    0.219093
# ESML    0.258273
# GOVT    0.059937
# MBB     0.060203
# SHY     0.017925
# SUSA    0.217391
# SUSB    0.044815
# SUSC    0.090203
# dtype: float64

# %% [markdown]
# ## Risk parity relaxed optim based on historical rets and cov

# %% [markdown]
# Build the linear constraint based on the ESG rating

# %%
import pandas as pd
from riskfolio import factors_constraints

# Your DataFrame
ESG_constraint_data = {
    'ESG Fund Rating': [6.6, 8.6, 7.1, 7.3, 6.5, 5.7, 6, 5.7, 8.2, 7.9, 7.6],
}

ESG_constraint = pd.DataFrame(ESG_constraint_data)

# Define the constraints based on your DataFrame
constraints = pd.DataFrame({
    'Disabled': [False],
    'Factor': ['ESG Fund Rating'],
    'Sign': ['>='],
    'Value': [7],
    'Relative Factor': '',
})

# Create the factors constraints matrices C and D
C, D = factors_constraints(constraints, loadings=ESG_constraint)

# %%
# Building the portfolio object nea== minimal number of assets to include
port = rp.Portfolio(returns=rets,ainequality = C, binequality = D, nea = 6)

# Select method and estimate input parameters:

method_mu='hist' # Method to estimate expected returns based on historical data.
method_cov='hist' # Method to estimate covariance matrix based on historical data.

port.assets_stats(method_mu=method_mu, method_cov=method_cov, d=0.94)

# Estimate optimal portfolio:

model = 'Classic' # Could be Classic (historical) or FM (Factor Model)
rm = 'MV' # Risk measure used, this time will be variance
obj = 'MinRisk' # Objective function, could be MinRisk, MaxRet, Utility or Sharpe
hist = True # Use historical scenarios for risk measures that depend on scenarios
rf = 0 # Risk free rate
b = None # Risk contribution constraints vector

# %% [markdown]
# ## Minimum Variance Portfolio

# %%
model='Classic' # Could be Classic (historical), BL (Black Litterman) or FM (Factor Model)
rm = 'MV' # Risk measure used, this time will be variance
obj = 'MinRisk' # Objective function, could be MinRisk, MaxRet, Utility or Sharpe
hist = True # Use historical scenarios for risk measures that depend on scenarios
rf = 0 # Risk free rate
l = 0 # Risk aversion factor, only useful when obj is 'Utility'

w = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)

display(w.T)

# Plotting the composition of the portfolio

ax = rp.plot_pie(w=w, title='Minnimum Variance Portfolio', others=0.05, nrow=25, cmap = "tab20",
                 height=6, width=10, ax=None)


w_weights = w['weights'].values.reshape(1, -1)
esg_ratings = ESG_constraint['ESG Fund Rating'].values.reshape(-1, 1)

ESG_Rating_portfolio = w_weights.dot(esg_ratings).item()
print(f'The weighted average ESG rating of this portfolio is {ESG_Rating_portfolio}')
# Out:
#              EAGG      ESGD          ESGE          ESGU          ESML  \
# weights  0.139171  0.074286  1.792132e-08  1.401191e-08  4.171648e-09
#
#              GOVT      MBB       SHY      SUSA     SUSB      SUSC
# weights  0.096029  0.08109  0.173064  0.034155  0.28471  0.117495
# The weighted average ESG rating of this portfolio is 7.000000007867602

# %% [markdown]
# ## Risk Parity Portfolio

# %%
version = 'A' # Could be A, B or C

w_rrp_a = port.rrp_optimization(model=model, version=version, l=l, b= None, hist=hist)

display(w_rrp_a.T)
# Plotting the composition of the portfolio

ax = rp.plot_pie(w=w_rrp_a, title='Relaxed Risk Parity A', others=0.05, nrow=25, cmap = "tab20",
                 height=6, width=10, ax=None)


w_rrp_a_weights = w_rrp_a['weights'].values.reshape(1, -1)
esg_ratings = ESG_constraint['ESG Fund Rating'].values.reshape(-1, 1)

ESG_Rating_portfolio = w_rrp_a_weights.dot(esg_ratings).item()
print(f'The weighted average ESG rating of this portfolio is {ESG_Rating_portfolio}')
# Out:
# /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages/cvxpy/problems/problem.py:1387: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
#              EAGG      ESGD      ESGE      ESGU      ESML      GOVT       MBB  \
# weights  0.100898  0.035478  0.038566  0.035453  0.032342  0.106401  0.091782
#
#               SHY     SUSA      SUSB      SUSC
# weights  0.125158  0.03339  0.325645  0.074888
# The weighted average ESG rating of this portfolio is 7.000000203108467

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10,6))

# Plotting the risk composition of the portfolio
ax = rp.plot_risk_con(w_rrp_a, cov=port.cov, returns=port.returns, rm=rm, rf=0, alpha=0.05,
                      color="tab:blue", height=6, width=10, ax=ax)

# Plotting equal risk contribution line
a1 = rp.Sharpe_Risk(w_rrp_a, cov=port.cov, returns=port.returns, rm=rm, rf=0, alpha=0.05)
ax.axhline(y=a1/len(assets) * 252**0.5, color='r', linestyle='-')

# %% [markdown]
# # Views on Black Litterman Portfolio

# %%
asset_classes = {'Assets':["ESGU", "EAGG", "ESGE", "ESML", "SUSB", "ESGD", "SHY", "SUSA", "GOVT", "MBB", "SUSC"]}

asset_classes = pd.DataFrame(asset_classes)
asset_classes = asset_classes.sort_values(by=['Assets'])

views = {'Disabled': [False, False, False],
         'Type': ['Assets', 'Assets', 'Assets'],
         'Set': ['', '', ''],
         'Position': ['SHY', 'ESGE', 'SUSB'],
         'Sign': ['<=', '>=', '>='],
         'Return': [0.08, 0.5, 0], # Annual terms 
         'Type Relative': [ '', '', ''],
         'Relative Set': [ '', '', ''],
         'Relative': ['', '', '']
}

views = pd.DataFrame(views)

display(views)
# Out:
#    Disabled    Type Set Position Sign  Return Type Relative Relative Set  \
# 0     False  Assets          SHY   <=    0.08
# 1     False  Assets         ESGE   >=    0.50
# 2     False  Assets         SUSB   >=    0.00
#
#   Relative
# 0
# 1
# 2

# %%
P,Q = rp.assets_views(views, asset_classes)

# %% [markdown]
# ## Black Litterman optimization

# %%
# Estimate Black Litterman inputs:

port.blacklitterman_stats(P, Q/252, rf=rf, w=w, delta=None, eq=True)

# Estimate optimal portfolio:

model='BL'# Black Litterman
rm = 'MV' # Risk measure used, this time will be variance
obj = 'Sharpe' # Objective function, could be MinRisk, MaxRet, Utility or Sharpe
hist = False # Use historical scenarios for risk measures that depend on scenarios

w_bl = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)

display(w_bl.T)
# Out:
#              EAGG      ESGD      ESGE          ESGU          ESML      GOVT  \
# weights  0.227284  0.086523  0.074367  2.994087e-07  1.328173e-07  0.126737
#
#               MBB       SHY      SUSA      SUSB      SUSC
# weights  0.145607  0.010168  0.000007  0.236775  0.092531

# %%
# Plotting the composition of the portfolio

ax = rp.plot_pie(w=w_bl, title='Sharpe Black Litterman', others=0.05, nrow=25,
                 cmap = "tab20", height=6, width=10, ax=None)

w_bl_weights = w_bl['weights'].values.reshape(1, -1)

ESG_Rating_BLportfolio = w_bl_weights.dot(esg_ratings).item()
print(f'The weighted average ESG rating of this BL portfolio is {ESG_Rating_BLportfolio}')
# Out:
# The weighted average ESG rating of this BL portfolio is 7.000000329719693

# %%
points = 100 # Number of points of the frontier

frontier = port.efficient_frontier(model=model, rm=rm, points=points, rf=rf, hist=hist)

display(frontier.T.head())
# Out:
#        EAGG      ESGD          ESGE          ESGU          ESML      GOVT  \
# 0  0.139170  0.074287  1.794721e-08  1.401746e-08  4.173222e-09  0.096029
# 1  0.170768  0.081255  2.842424e-02  8.493422e-10  3.359471e-10  0.099712
# 2  0.187993  0.081905  4.112922e-02  5.209173e-09  2.068473e-09  0.104014
# 3  0.200817  0.082807  4.991220e-02  5.582688e-09  2.355564e-09  0.108634
# 4  0.210475  0.083912  5.698324e-02  7.052657e-09  2.962385e-09  0.113218
#
#         MBB       SHY      SUSA      SUSB      SUSC
# 0  0.081093  0.173062  0.034152  0.284710  0.117497
# 1  0.095220  0.131558  0.012518  0.293263  0.087283
# 2  0.105536  0.104030  0.006575  0.289503  0.079314
# 3  0.115017  0.080634  0.003317  0.282040  0.076822
# 4  0.123649  0.060250  0.001187  0.272569  0.077757

# %%
# Plotting the efficient frontier

label = 'Max Risk Adjusted Return Portfolio' # Title of point
mu = port.mu_bl # Expected returns of Black Litterman model
cov = port.cov_bl # Covariance matrix of Black Litterman model
returns = port.returns # Returns of the assets

ax = rp.plot_frontier(w_frontier=frontier, mu=mu, cov=cov, returns=returns, rm=rm,
                      rf=rf, alpha=0.05, cmap='viridis', w=w_bl, label=label,
                      marker='*', s=16, c='r', height=6, width=10, ax=None)

# %%
# Plotting efficient frontier composition

ax = rp.plot_frontier_area(w_frontier=frontier, cmap="tab20", height=6, width=10, ax=None)

# %%
# Risk Measures available:
#
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'EVaR': Entropic Value at Risk.
# 'WR': Worst Realization (Minimax)
# 'MDD': Maximum Drawdown of uncompounded cumulative returns (Calmar Ratio).
# 'ADD': Average Drawdown of uncompounded cumulative returns.
# 'CDaR': Conditional Drawdown at Risk of uncompounded cumulative returns.
# 'EDaR': Entropic Drawdown at Risk of uncompounded cumulative returns.
# 'UCI': Ulcer Index of uncompounded cumulative returns.

rms = ['MV', 'MAD', 'MSV', 'FLPM', 'SLPM', 'CVaR',
       'EVaR', 'WR', 'MDD', 'ADD', 'CDaR', 'UCI', 'EDaR']

w_s = pd.DataFrame([])
port.alpha = 0.05

for i in rms:
    if i == 'MV':
        hist = False
    else:
        hist = True
    w = port.optimization(model=model, rm=i, obj=obj, rf=rf, l=l, hist=hist)
    w_s = pd.concat([w_s, w], axis=1)
    
w_s.columns = rms
# Out:
# /Users/remimailhot/opt/anaconda3/lib/python3.8/site-packages/cvxpy/problems/problem.py:1387: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(

# %%
w_s.style.format("{:.2%}").background_gradient(cmap='YlGn')
# Out:
# <style type="text/css">
# #T_50a1c_row0_col0, #T_50a1c_row3_col9, #T_50a1c_row6_col10, #T_50a1c_row7_col11 {
#   background-color: #00502d;
#   color: #f1f1f1;
# }
# #T_50a1c_row0_col1 {
#   background-color: #51b365;
#   color: #f1f1f1;
# }
# #T_50a1c_row0_col2 {
#   background-color: #005a31;
#   color: #f1f1f1;
# }
# #T_50a1c_row0_col3 {
#   background-color: #56b568;
#   color: #f1f1f1;
# }
# #T_50a1c_row0_col4 {
#   background-color: #005530;
#   color: #f1f1f1;
# }
# #T_50a1c_row0_col5, #T_50a1c_row3_col8, #T_50a1c_row3_col10, #T_50a1c_row3_col11, #T_50a1c_row3_col12, #T_50a1c_row7_col9, #T_50a1c_row9_col0, #T_50a1c_row9_col1, #T_50a1c_row9_col2, #T_50a1c_row9_col3, #T_50a1c_row9_col4, #T_50a1c_row9_col6, #T_50a1c_row9_col7 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_50a1c_row0_col6 {
#   background-color: #004c2c;
#   color: #f1f1f1;
# }
# #T_50a1c_row0_col7 {
#   background-color: #056c39;
#   color: #f1f1f1;
# }
# #T_50a1c_row0_col8, #T_50a1c_row0_col9, #T_50a1c_row0_col10, #T_50a1c_row0_col11, #T_50a1c_row0_col12, #T_50a1c_row2_col6, #T_50a1c_row2_col9, #T_50a1c_row3_col0, #T_50a1c_row3_col1, #T_50a1c_row3_col2, #T_50a1c_row3_col3, #T_50a1c_row3_col4, #T_50a1c_row3_col5, #T_50a1c_row3_col6, #T_50a1c_row3_col7, #T_50a1c_row4_col0, #T_50a1c_row4_col1, #T_50a1c_row4_col2, #T_50a1c_row4_col3, #T_50a1c_row4_col4, #T_50a1c_row4_col5, #T_50a1c_row4_col6, #T_50a1c_row4_col7, #T_50a1c_row4_col9, #T_50a1c_row4_col10, #T_50a1c_row4_col11, #T_50a1c_row8_col0, #T_50a1c_row8_col2, #T_50a1c_row8_col4, #T_50a1c_row8_col5, #T_50a1c_row10_col8, #T_50a1c_row10_col9, #T_50a1c_row10_col10, #T_50a1c_row10_col11, #T_50a1c_row10_col12 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_50a1c_row1_col0, #T_50a1c_row2_col5 {
#   background-color: #b1df90;
#   color: #000000;
# }
# #T_50a1c_row1_col1 {
#   background-color: #e2f4aa;
#   color: #000000;
# }
# #T_50a1c_row1_col2 {
#   background-color: #a7db8c;
#   color: #000000;
# }
# #T_50a1c_row1_col3 {
#   background-color: #e4f4ab;
#   color: #000000;
# }
# #T_50a1c_row1_col4 {
#   background-color: #a4d98a;
#   color: #000000;
# }
# #T_50a1c_row1_col5 {
#   background-color: #4eb163;
#   color: #f1f1f1;
# }
# #T_50a1c_row1_col6, #T_50a1c_row2_col3 {
#   background-color: #f0f9b4;
#   color: #000000;
# }
# #T_50a1c_row1_col7 {
#   background-color: #fbfdcf;
#   color: #000000;
# }
# #T_50a1c_row1_col8 {
#   background-color: #feffe1;
#   color: #000000;
# }
# #T_50a1c_row1_col9 {
#   background-color: #0c723b;
#   color: #f1f1f1;
# }
# #T_50a1c_row1_col10 {
#   background-color: #e9f6af;
#   color: #000000;
# }
# #T_50a1c_row1_col11 {
#   background-color: #167a3f;
#   color: #f1f1f1;
# }
# #T_50a1c_row1_col12, #T_50a1c_row8_col1, #T_50a1c_row8_col3 {
#   background-color: #f9fdc5;
#   color: #000000;
# }
# #T_50a1c_row2_col0, #T_50a1c_row7_col7, #T_50a1c_row8_col7 {
#   background-color: #c3e698;
#   color: #000000;
# }
# #T_50a1c_row2_col1 {
#   background-color: #eff9b3;
#   color: #000000;
# }
# #T_50a1c_row2_col2, #T_50a1c_row2_col4 {
#   background-color: #def2a7;
#   color: #000000;
# }
# #T_50a1c_row2_col7, #T_50a1c_row4_col12 {
#   background-color: #fbfdce;
#   color: #000000;
# }
# #T_50a1c_row2_col8 {
#   background-color: #2d914b;
#   color: #f1f1f1;
# }
# #T_50a1c_row2_col10 {
#   background-color: #0b713b;
#   color: #f1f1f1;
# }
# #T_50a1c_row2_col11, #T_50a1c_row5_col12 {
#   background-color: #f8fcbd;
#   color: #000000;
# }
# #T_50a1c_row2_col12 {
#   background-color: #3fa85b;
#   color: #f1f1f1;
# }
# #T_50a1c_row4_col8 {
#   background-color: #dff3a8;
#   color: #000000;
# }
# #T_50a1c_row5_col0 {
#   background-color: #68be71;
#   color: #000000;
# }
# #T_50a1c_row5_col1, #T_50a1c_row7_col6, #T_50a1c_row10_col5 {
#   background-color: #e3f4aa;
#   color: #000000;
# }
# #T_50a1c_row5_col2 {
#   background-color: #64bc6f;
#   color: #f1f1f1;
# }
# #T_50a1c_row5_col3 {
#   background-color: #e8f6ae;
#   color: #000000;
# }
# #T_50a1c_row5_col4 {
#   background-color: #5ab76a;
#   color: #f1f1f1;
# }
# #T_50a1c_row5_col5 {
#   background-color: #12763d;
#   color: #f1f1f1;
# }
# #T_50a1c_row5_col6 {
#   background-color: #298c48;
#   color: #f1f1f1;
# }
# #T_50a1c_row5_col7 {
#   background-color: #369d54;
#   color: #f1f1f1;
# }
# #T_50a1c_row5_col8 {
#   background-color: #fafdc9;
#   color: #000000;
# }
# #T_50a1c_row5_col9 {
#   background-color: #cbea9c;
#   color: #000000;
# }
# #T_50a1c_row5_col10 {
#   background-color: #f7fcb9;
#   color: #000000;
# }
# #T_50a1c_row5_col11 {
#   background-color: #d7efa2;
#   color: #000000;
# }
# #T_50a1c_row6_col0 {
#   background-color: #45ad5f;
#   color: #f1f1f1;
# }
# #T_50a1c_row6_col1, #T_50a1c_row6_col3, #T_50a1c_row10_col7 {
#   background-color: #2c8f4b;
#   color: #f1f1f1;
# }
# #T_50a1c_row6_col2 {
#   background-color: #5cb86b;
#   color: #f1f1f1;
# }
# #T_50a1c_row6_col4 {
#   background-color: #61bb6d;
#   color: #f1f1f1;
# }
# #T_50a1c_row6_col5 {
#   background-color: #9cd687;
#   color: #000000;
# }
# #T_50a1c_row6_col6, #T_50a1c_row9_col8 {
#   background-color: #c0e597;
#   color: #000000;
# }
# #T_50a1c_row6_col7 {
#   background-color: #e7f6ad;
#   color: #000000;
# }
# #T_50a1c_row6_col8 {
#   background-color: #006536;
#   color: #f1f1f1;
# }
# #T_50a1c_row6_col9 {
#   background-color: #10743c;
#   color: #f1f1f1;
# }
# #T_50a1c_row6_col11 {
#   background-color: #1d7f41;
#   color: #f1f1f1;
# }
# #T_50a1c_row6_col12 {
#   background-color: #15793e;
#   color: #f1f1f1;
# }
# #T_50a1c_row7_col0 {
#   background-color: #fcfed7;
#   color: #000000;
# }
# #T_50a1c_row7_col1 {
#   background-color: #ccea9d;
#   color: #000000;
# }
# #T_50a1c_row7_col2 {
#   background-color: #f9fdc4;
#   color: #000000;
# }
# #T_50a1c_row7_col3 {
#   background-color: #c5e89a;
#   color: #000000;
# }
# #T_50a1c_row7_col4 {
#   background-color: #f9fdc7;
#   color: #000000;
# }
# #T_50a1c_row7_col5 {
#   background-color: #fafdc8;
#   color: #000000;
# }
# #T_50a1c_row7_col8 {
#   background-color: #b6e192;
#   color: #000000;
# }
# #T_50a1c_row7_col10 {
#   background-color: #75c578;
#   color: #000000;
# }
# #T_50a1c_row7_col12, #T_50a1c_row8_col11 {
#   background-color: #7cc87b;
#   color: #000000;
# }
# #T_50a1c_row8_col6 {
#   background-color: #acdd8e;
#   color: #000000;
# }
# #T_50a1c_row8_col8, #T_50a1c_row8_col10 {
#   background-color: #288a47;
#   color: #f1f1f1;
# }
# #T_50a1c_row8_col9 {
#   background-color: #7ec97b;
#   color: #000000;
# }
# #T_50a1c_row8_col12 {
#   background-color: #258745;
#   color: #f1f1f1;
# }
# #T_50a1c_row9_col5 {
#   background-color: #00512e;
#   color: #f1f1f1;
# }
# #T_50a1c_row9_col9 {
#   background-color: #bce395;
#   color: #000000;
# }
# #T_50a1c_row9_col10 {
#   background-color: #d9f0a3;
#   color: #000000;
# }
# #T_50a1c_row9_col11 {
#   background-color: #e5f5ac;
#   color: #000000;
# }
# #T_50a1c_row9_col12 {
#   background-color: #daf0a4;
#   color: #000000;
# }
# #T_50a1c_row10_col0, #T_50a1c_row10_col3 {
#   background-color: #a6da8b;
#   color: #000000;
# }
# #T_50a1c_row10_col1, #T_50a1c_row10_col4 {
#   background-color: #aedd8e;
#   color: #000000;
# }
# #T_50a1c_row10_col2 {
#   background-color: #afde8f;
#   color: #000000;
# }
# #T_50a1c_row10_col6 {
#   background-color: #69bf72;
#   color: #000000;
# }
# </style>
# <table id="T_50a1c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MV</th>
#       <th class="col_heading level0 col1" >MAD</th>
#       <th class="col_heading level0 col2" >MSV</th>
#       <th class="col_heading level0 col3" >FLPM</th>
#       <th class="col_heading level0 col4" >SLPM</th>
#       <th class="col_heading level0 col5" >CVaR</th>
#       <th class="col_heading level0 col6" >EVaR</th>
#       <th class="col_heading level0 col7" >WR</th>
#       <th class="col_heading level0 col8" >MDD</th>
#       <th class="col_heading level0 col9" >ADD</th>
#       <th class="col_heading level0 col10" >CDaR</th>
#       <th class="col_heading level0 col11" >UCI</th>
#       <th class="col_heading level0 col12" >EDaR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_50a1c_level0_row0" class="row_heading level0 row0" >EAGG</th>
#       <td id="T_50a1c_row0_col0" class="data row0 col0" >22.73%</td>
#       <td id="T_50a1c_row0_col1" class="data row0 col1" >16.18%</td>
#       <td id="T_50a1c_row0_col2" class="data row0 col2" >22.49%</td>
#       <td id="T_50a1c_row0_col3" class="data row0 col3" >15.81%</td>
#       <td id="T_50a1c_row0_col4" class="data row0 col4" >22.66%</td>
#       <td id="T_50a1c_row0_col

# %%
# Plotting a comparison of assets weights for each portfolio

fig = plt.gcf()
fig.set_figwidth(14)
fig.set_figheight(6)
ax = fig.subplots(nrows=1, ncols=1)

w_s.plot.bar(ax=ax)
# Out:
# <Axes: >
